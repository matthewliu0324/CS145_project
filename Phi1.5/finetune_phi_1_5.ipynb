# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd /content/drive/MyDrive/Ucla/LLama3/lr_code

# %%
# !pip install -r /content/drive/MyDrive/Ucla/LLama3/requirments.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.2/309.2 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.6/416.6 kB 30.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 76.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 33.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 41.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 114.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 18.5 MB/s eta 0:00:00
# ...

# %%
# !huggingface-cli login
# Use this key to login: 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
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !chmod +x /content/drive/MyDrive/Ucla/LLama3/train.sh

# %%
# !/content/drive/MyDrive/Ucla/LLama3/train.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# {'loss': 0.3422, 'grad_norm': 4.286430835723877, 'learning_rate': 2.9210886112960473e-05, 'epoch': 0.1}
# {'loss': 0.3289, 'grad_norm': 2.2226524353027344, 'learning_rate': 2.9232807233006683e-05, 'epoch': 0.1}
# {'loss': 0.3803, 'grad_norm': 2.8734641075134277, 'learning_rate': 2.925462983083261e-05, 'epoch': 0.1}
# {'loss': 0.3445, 'grad_norm': 4.100480079650879, 'learning_rate': 2.9276354788073292e-05, 'epoch': 0.1}
# {'loss': 0.3499, 'grad_norm': 4.064551830291748, 'learning_rate': 2.929798297458238e-05, 'epoch': 0.1}
# {'loss': 0.2381, 'grad_norm': 3.6756832599639893, 'learning_rate': 2.931951524864111e-05, 'epoch': 0.1}
# {'loss': 0.2951, 'grad_norm': 3.3564038276672363, 'learning_rate': 2.9340952457162687e-05, 'epoch': 0.11}
# {'loss': 0.306, 'grad_norm': 3.499439239501953, 'learning_rate': 2.936229543589214e-05, 'epoch': 0.11}
# ...

# %%
# !python3 /content/drive/MyDrive/Ucla/LLama3/inference.py --lora_path matthewliu0324/text-20240610-185727-3e-5 --saved_dir /content/drive/MyDrive/Ucla/LLama3/output --eval_path /content/drive/MyDrive/Ucla/LLama3/dataset/train_author_inference.json
# Out:
# ^C

# %%
import json
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_true = []
auc_scores = []

with open('/content/drive/MyDrive/Ucla/LLama3/dataset/train_author_inference_labels.json', 'r') as f:
    data = json.load(f)
    for paper_id, values in data.items():
      for key, val in values["papers"].items():
        y_true.append(values["papers"][key])

with open('/content/drive/MyDrive/Ucla/LLama3/output/result-text-20240610-185727-3e-5.json', 'r') as f:
    data = json.load(f)
    for paper_id, values in data.items():
      for key, val in values.items():
        auc_scores.append(val)

fpr, tpr, thresholds = roc_curve(y_true, auc_scores)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='firebrick', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
roc_auc
# Out:
# 0.8018140008955265

# %%
import json
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

authors_true_score = []
authors_auc_scores = []
errors_of_authors = []
total_errors =

with open('/content/drive/MyDrive/Ucla/LLama3/dataset/train_author_inference_labels.json', 'r') as f:
    data = json.load(f)
    for paper_id, values in data.items():
      y_true = []
      for key, val in values["papers"].items():
        y_true.append(values["papers"][key])
      authros_true_score.append(y_true)

with open('/content/drive/MyDrive/Ucla/LLama3/output/result-text-20240610-185727-3e-5.json', 'r') as f:
    data = json.load(f)
    for paper_id, values in data.items():
      auc_scores = []
      i= 0
      for key, val in values.items():
        auc_scores.append(val)

fpr, tpr, thresholds = roc_curve(y_true, auc_scores)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='firebrick', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()

plt.show()
